# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv("Dataset-1.csv")
dataset
# Out:
#        2  2.1   0  0.1  6  1  1.1  2016  85  74.8  ...  89.4  65  21  9.5  \
# 0      2    2   1    0  6  1    1  2016  85  74.8  ...  89.4  65  21  9.5
# 1      2    2   2    0  6  1    1  2016  85  74.8  ...  89.4  65  21  9.5
# 2      2    2   3    0  6  1    1  2016  85  74.8  ...  89.4  65  21  9.5
# 3      2    2   4    0  6  1    1  2016  85  74.8  ...  89.4  65  21  9.5
# 4      2    2   5    0  6  1    1  2016  85  74.8  ...  89.4  65  21  9.5
# ...   ..  ...  ..  ... .. ..  ...   ...  ..   ...  ...   ...  ..  ..  ...
# 35946  1    2  19    0  7  7    3  2020  93  84.5  ...  76.6  53  15  6.1
# 35947  1    2  20    0  7  7    3  2020  93  84.5  ...  76.6  53  15  6.1
# 35948  1    2  21    0  7  7    3  2020  93  84.5  ...  76.6  53  15  6.1
# 35949  1    2  22    0  7  7    3  2020  93  84.5  ...  76.6  53  15  6.1
# 35950  1    2  23    0  7  7    3  2020  93  84.5  ...  76.6  53  15  6.1
#
#        0.2  29.8  29.8.1  29.7  0.3  1.057
# ...

# %%
dataset.drop(dataset.iloc[:, 1:24], inplace=True, axis=1)
print("Data does does not have any meaning but for results we will use for the first and last column")
dataset
X = dataset.iloc[:, :-1].values #get a copy of dataset exclude last column
y = dataset.iloc[:, 0].values #get array of dataset in column 1st
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)

X_train

# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)
# Import metrics library
from sklearn import metrics
print("Dataset-1")
print("using the col 1 and last col")
# Print result of MAE
print("MAE:",metrics.mean_absolute_error (y_test, y_pred))
# Print result of MSE
print("MSE:",metrics. mean_squared_error (y_test, y_pred))
# Print result of RMSE
print("RMSE:",np. sqrt (metrics .mean_squared_error (y_test, y_pred)))
# Out:
# Data does does not have any meaning but for results we will use for the first and last column
# Dataset-1
# using the col 1 and last col
# MAE: 2.2470992246625548e-13
# MSE: 6.870366724159489e-26
# RMSE: 2.621138440479535e-13

# %%
df = pd.read_csv("Dataset-2.csv")
df_binary = df[['radius_mean', 'fractal_dimension_worst']]
df_binary
X = df_binary.iloc[:, :-1].values #get a copy of dataset exclude last column
y = df_binary.iloc[:, 1].values #get array of dataset in column 1st
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)


# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)
# Import metrics library
from sklearn import metrics
print("Dataset-2")
print("using the first column and 2nd last column")
# Print result of MAE
print("MAE:",metrics.mean_absolute_error (y_test, y_pred))
# Print result of MSE
print("MSE:",metrics. mean_squared_error (y_test, y_pred))
# Print result of RMSE
print("RMSE:",np. sqrt (metrics .mean_squared_error (y_test, y_pred)))
# Out:
# Dataset-2
# using the first column and 2nd last column
# MAE: 0.013868989304813843
# MSE: 0.0003351596353380823
# RMSE: 0.018307365603441754

# %%
df = pd.read_csv("Dataset-3.csv")
df_binary = df[['Mean1', 'Energy1']]
df_binary
X = df_binary.iloc[:, :-1].values #get a copy of dataset exclude last column
y = df_binary.iloc[:, 0].values #get array of dataset in column 1st
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)


# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)
# Import metrics library
from sklearn import metrics
print("Dataset-3")
print("using the Mean1 and Energy1")
# Print result of MAE
print("MAE:",metrics.mean_absolute_error (y_test, y_pred))
# Print result of MSE
print("MSE:",metrics. mean_squared_error (y_test, y_pred))
# Print result of RMSE
print("RMSE:",np. sqrt (metrics .mean_squared_error (y_test, y_pred)))
# Out:
# Dataset-3
# using the Mean1 and Energy1
# MAE: 8.628018934229787e-15
# MSE: 1.8151313781085377e-28
# RMSE: 1.3472681166377158e-14

# %%
df = pd.read_csv("Dataset-4.csv")
df
df_binary = df[['Temperature', "diffuse flows"]]
df_binary
X = df_binary.iloc[:, :-1].values #get a copy of dataset exclude last column
y = df_binary.iloc[:, 1].values #get array of dataset in column 1st
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)


# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)
# Import metrics library
from sklearn import metrics
print("Dataset-4")
print("using the Temperature and Zone 3 Power Consumption")
# Print result of MAE
print("MAE:",metrics.mean_absolute_error (y_test, y_pred))
# Print result of MSE
print("MSE:",metrics. mean_squared_error (y_test, y_pred))
# Print result of RMSE
print("RMSE:",np. sqrt (metrics .mean_squared_error (y_test, y_pred)))
# Out:
# Dataset-4
# using the Temperature and Zone 3 Power Consumption
# MAE: 83.53050534969545
# MSE: 15203.563849870177
# RMSE: 123.30273253204966

# %%
df = pd.read_csv("Dataset-5.csv")
df
df_binary = df[['SepalLengthCm', "SepalWidthCm"]]
df_binary
X = df_binary.iloc[:, :-1].values #get a copy of dataset exclude last column
y = df_binary.iloc[:, 1].values #get array of dataset in column 1st
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)


# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)
# Import metrics library
from sklearn import metrics
print("Dataset-5")
print("using the SepalLengthCm and SepalWidthCm")
# Print result of MAE
print("MAE:",metrics.mean_absolute_error (y_test, y_pred))
# Print result of MSE
print("MSE:",metrics. mean_squared_error (y_test, y_pred))
# Print result of RMSE
print("RMSE:",np. sqrt (metrics .mean_squared_error (y_test, y_pred)))
# Out:
# Dataset-5
# using the SepalLengthCm and SepalWidthCm
# MAE: 0.3190945706102275
# MSE: 0.16912275711721653
# RMSE: 0.41124537336876693

# %%
df = pd.read_csv("Dataset-6.csv")

X = df_binary.iloc[:, :-1].values #get a copy of dataset exclude last column
y = df_binary.iloc[:, 1].values #get array of dataset in column 1st
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)


# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)
# Import metrics library
from sklearn import metrics
print("Dataset-6")
# Print result of MAE
print("MAE:",metrics.mean_absolute_error (y_test, y_pred))
# Print result of MSE
print("MSE:",metrics. mean_squared_error (y_test, y_pred))
# Print result of RMSE
print("RMSE:",np. sqrt (metrics .mean_squared_error (y_test, y_pred)))
# Out:
# Dataset-6
# MAE: 0.3190945706102275
# MSE: 0.16912275711721653
# RMSE: 0.41124537336876693
